# %%
# !unzip tatrach-autoformer-main.zip
# Out:
# Archive:  tatrach-autoformer-main.zip
#    creating: tatrach-autoformer-main/
#   inflating: tatrach-autoformer-main/.gitignore
#    creating: tatrach-autoformer-main/dataset/
#   inflating: tatrach-autoformer-main/dataset/Data_TaTrach.csv
#    creating: tatrach-autoformer-main/dataset/ETT-small/
#   inflating: tatrach-autoformer-main/dataset/ETT-small/ETTh1.csv
#    creating: tatrach-autoformer-main/data_provider/
#   inflating: tatrach-autoformer-main/data_provider/data_factory.py
#   inflating: tatrach-autoformer-main/data_provider/data_loader.py
#  extracting: tatrach-autoformer-main/data_provider/__init__.py
#   inflating: tatrach-autoformer-main/Dockerfile
#   inflating: tatrach-autoformer-main/environment.yml
#    creating: tatrach-autoformer-main/exp/
#   inflating: tatrach-autoformer-main/exp/exp_basic.py
#   inflating: tatrach-autoformer-main/exp/exp_main.py
#  extracting: tatrach-autoformer-main/exp/__init__.py
#    creating: tatrach-autoformer-main/layers/
#   inflating: tatrach-autoformer-main/layers/AutoCorrelation.py
#   inflating: tatrach-autoformer-main/layers/Autoformer_EncDec.py
#   inflating: tatrach-autoformer-main/layers/Embed.py
#   inflating: tatrach-autoformer-main/layers/SelfAttention_Family.py
#   inflating: tatrach-autoformer-main/layers/Transformer_EncDec.py
#  extracting: tatrach-autoformer-main/layers/__init__.py
#   inflating: tatrach-autoformer-main/LICENSE
#   inflating: tatrach-autoformer-main/Makefile
#    creating: tatrach-autoformer-main/models/
#   inflating: tatrach-autoformer-main/models/Autoformer.py
#   inflating: tatrach-autoformer-main/models/Informer.py
#   inflating: tatrach-autoformer-main/models/Reformer.py
#   inflating: tatrach-autoformer-main/models/Transformer.py
#  extracting: tatrach-autoformer-main/models/__init__.py
#    creating: tatrach-autoformer-main/pic/
#   inflating: tatrach-autoformer-main/pic/Auto-Correlation.png
#   inflating: tatrach-autoformer-main/pic/Autoformer.png
#   inflating: tatrach-autoformer-main/pic/results.png
#   inflating: tatrach-autoformer-main/predict.ipynb
#   inflating: tatrach-autoformer-main/README.md
#   inflating: tatrach-autoformer-main/requirements.txt
#   inflating: tatrach-autoformer-main/run.py
#    creating: tatrach-autoformer-main/scripts/
#    creating: tatrach-autoformer-main/scripts/ECL_script/
#   inflating: tatrach-autoformer-main/scripts/ECL_script/Autoformer.sh
#   inflating: tatrach-autoformer-main/scripts/ECL_script/Informer.sh
#   inflating: tatrach-autoformer-main/scripts/ECL_script/Reformer.sh
#   inflating: tatrach-autoformer-main/scripts/ECL_script/Transformer.sh
#    creating: tatrach-autoformer-main/scripts/ETT_script/
#   inflating: tatrach-autoformer-main/scripts/ETT_script/Autoformer_ETTh1.sh
#   inflating: tatrach-autoformer-main/scripts/ETT_script/Autoformer_ETTh2.sh
#   inflating: tatrach-autoformer-main/scripts/ETT_script/Autoformer_ETTm1.sh
#   inflating: tatrach-autoformer-main/scripts/ETT_script/Autoformer_ETTm2.sh
#   inflating: tatrach-autoformer-main/scripts/ETT_script/Autoformer_univariate.sh
#   inflating: tatrach-autoformer-main/scripts/ETT_script/Informer.sh
#   inflating: tatrach-autoformer-main/scripts/ETT_script/Reformer.sh
#   inflating: tatrach-autoformer-main/scripts/ETT_script/Transformer.sh
#    creating: tatrach-autoformer-main/scripts/Exchange_script/
#   inflating: tatrach-autoformer-main/scripts/Exchange_script/Autoformer.sh
#   inflating: tatrach-autoformer-main/scripts/Exchange_script/Autoformer_univariate.sh
#   inflating: tatrach-autoformer-main/scripts/Exchange_script/Informer.sh
#   inflating: tatrach-autoformer-main/scripts/Exchange_script/Reformer.sh
#   inflating: tatrach-autoformer-main/scripts/Exchange_script/Transformer.sh
#    creating: tatrach-autoformer-main/scripts/ILI_script/
#   inflating: tatrach-autoformer-main/scripts/ILI_script/Autoformer.sh
#   inflating: tatrach-autoformer-main/scripts/ILI_script/Informer.sh
#   inflating: tatrach-autoformer-main/scripts/ILI_script/Reformer.sh
#   inflating: tatrach-autoformer-main/scripts/ILI_script/Transformer.sh
#    creating: tatrach-autoformer-main/scripts/Traffic_script/
#   inflating: tatrach-autoformer-main/scripts/Traffic_script/Autoformer.sh
#   inflating: tatrach-autoformer-main/scripts/Traffic_script/Informer.sh
#   inflating: tatrach-autoformer-main/scripts/Traffic_script/Reformer.sh
#   inflating: tatrach-autoformer-main/scripts/Traffic_script/Transformer.sh
#    creating: tatrach-autoformer-main/scripts/Weather_script/
#   inflating: tatrach-autoformer-main/scripts/Weather_script/Autoformer.sh
#   inflating: tatrach-autoformer-main/scripts/Weather_script/Informer.sh
#   inflating: tatrach-autoformer-main/scripts/Weather_script/Reformer.sh
#   inflating: tatrach-autoformer-main/scripts/Weather_script/Transformer.sh
#   inflating: tatrach-autoformer-main/tatrach.ipynb
#  extracting: tatrach-autoformer-main/tatrach.rar
#    creating: tatrach-autoformer-main/utils/
#   inflating: tatrach-autoformer-main/utils/download_data.py
#   inflating: tatrach-autoformer-main/utils/masking.py
#   inflating: tatrach-autoformer-main/utils/metrics.py
#   inflating: tatrach-autoformer-main/utils/timefeatures.py
#   inflating: tatrach-autoformer-main/utils/tools.py
#  extracting: tatrach-autoformer-main/utils/__init__.py

# %%
# !pip install reformer-pytorch
# Out:
# Collecting reformer-pytorch
#   Downloading reformer_pytorch-1.4.4-py3-none-any.whl.metadata (764 bytes)
# Collecting axial-positional-embedding>=0.1.0 (from reformer-pytorch)
#   Downloading axial_positional_embedding-0.3.12-py3-none-any.whl.metadata (4.3 kB)
# Collecting einops (from reformer-pytorch)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting local-attention (from reformer-pytorch)
#   Downloading local_attention-1.11.2-py3-none-any.whl.metadata (929 bytes)
# Collecting product-key-memory (from reformer-pytorch)
#   Downloading product_key_memory-0.2.11-py3-none-any.whl.metadata (717 bytes)
# Requirement already satisfied: torch in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from reformer-pytorch) (2.8.0)
# Requirement already satisfied: filelock in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (1.14.0)
# Requirement already satisfied: networkx in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (3.1.6)
# Requirement already satisfied: fsspec in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from torch->reformer-pytorch) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from triton==3.4.0->torch->reformer-pytorch) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from sympy>=1.13.3->torch->reformer-pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from jinja2->torch->reformer-pytorch) (3.0.2)
# Collecting hyper-connections>=0.1.8 (from local-attention->reformer-pytorch)
#   Downloading hyper_connections-0.2.1-py3-none-any.whl.metadata (6.0 kB)
# Collecting colt5-attention>=0.10.14 (from product-key-memory->reformer-pytorch)
#   Downloading CoLT5_attention-0.11.1-py3-none-any.whl.metadata (737 bytes)
# Requirement already satisfied: packaging in /home/qminh/miniconda3/envs/testtorch/lib/python3.10/site-packages (from colt5-attention>=0.10.14->product-key-memory->reformer-pytorch) (25.0)
# Downloading reformer_pytorch-1.4.4-py3-none-any.whl (16 kB)
# Downloading axial_positional_embedding-0.3.12-py3-none-any.whl (6.7 kB)
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading local_attention-1.11.2-py3-none-any.whl (9.5 kB)
# Downloading hyper_connections-0.2.1-py3-none-any.whl (16 kB)
# Downloading product_key_memory-0.2.11-py3-none-any.whl (6.5 kB)
# Downloading CoLT5_attention-0.11.1-py3-none-any.whl (18 kB)
# Installing collected packages: einops, hyper-connections, axial-positional-embedding, local-attention, colt5-attention, product-key-memory, reformer-pytorch
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [reformer-pytorch]
# Successfully installed axial-positional-embedding-0.3.12 colt5-attention-0.11.1 einops-0.8.1 hyper-connections-0.2.1 local-attention-1.11.2 product-key-memory-0.2.11 reformer-pytorch-1.4.4

# %%
import sys
sys.path.append("tatrach-autoformer-main")
import argparse
import os
import torch
from exp.exp_main import Exp_Main#exp stands for experiments
import random
import numpy as np
from utils.tools import dotdict

# %%
def config_param(num_units,batch_size,learning_rate,dropout_rate,epochs):
    args = dotdict()
    args.target = 'OT'
    args.des = 'test'
    args.dropout = dropout_rate
    args.num_workers = 10
    args.gpu = 0
    args.lradj = 'type1'
    args.devices = '0'
    args.use_gpu = True
    args.use_multi_gpu = False
    # if args.use_gpu and args.use_multi_gpu: #是否使用多卡的判断
    #     args.dvices = args.devices.replace(' ', '')
    #     device_ids = args.devices.split(',')
    #     args.device_ids = [int(id_) for id_ in device_ids]
    #     args.gpu = args.device_ids[0]
    args.freq = 'h'
    args.checkpoints = './checkpoints/'
    args.bucket_size = 4
    args.n_hashes = 4
    args.seq_len = 180
    args.label_len = 180
    args.pred_len = 24
    args.e_layers = 2
    args.d_layers = 1
    args.n_heads = 8
    args.factor = 1
    args.d_model = num_units
    args.des = 'Exp'
    args.itr = 1
    args.d_ff = 2048
    args.moving_avg = 25
    args.distil = True
    args.output_attention = False
    args.patience= 3
    args.learning_rate = learning_rate
    args.batch_size = batch_size
    args.embed = 'timeF'
    args.activation = 'gelu'
    args.use_amp = False
    args.loss = 'mse'

    args.train_epochs = epochs
    args.is_training = True
    args.enc_in = 1
    args.dec_in = 1
    args.c_out = 1
    args.target = "q64"
    args.root_path = ''
    args.data_path ='/mnt/48AC6E9BAC6E82F4/Dev/gpu-test/data/mucnuoc_gio_preprocess.csv'
    args.model_id='q64'
    args.model = 'Autoformer'
    #args.model = 'Informer'
    args.data = 'custom'
    args.features = 'S'

    print('Args in experiment:')
    print(args)

    Exp = Exp_Main
    return args

# %%
def trainning(args):
    Exp = Exp_Main
    if args.is_training:
      for ii in range(args.itr):
          # setting record of experiments
          setting = '{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}'.format(
              args.model_id,
              args.model,
              args.data,
              args.features,
              args.seq_len,
              args.label_len,
              args.pred_len,
              args.d_model,
              args.n_heads,
              args.e_layers,
              args.d_layers,
              args.d_ff,
              args.factor,
              args.embed,
              args.distil,
              args.des, ii)

          exp = Exp(args)  # set experiments
          print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
          exp.train(setting)

          print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
          mae, rmse, r2=exp.test(setting)

          if args.do_predict:
              print('>>>>>>>predicting : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
              exp.predict(setting, True)
          torch.cuda.empty_cache()
          return mae, rmse, r2
    else:
      ii = 0
      setting = '{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}'.format(args.model_id,
                                                                                                    args.model,
                                                                                                    args.data,
                                                                                                    args.features,
                                                                                                    args.seq_len,
                                                                                                    args.label_len,
                                                                                                    args.pred_len,
                                                                                                    args.d_model,
                                                                                                    args.n_heads,
                                                                                                    args.e_layers,
                                                                                                    args.d_layers,
                                                                                                    args.d_ff,
                                                                                                    args.factor,
                                                                                                    args.embed,
                                                                                                    args.distil,
                                                                                                    args.des, ii)

      exp = Exp(args)  # set experiments
      print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
      exp.test(setting, test=1)
      torch.cuda.empty_cache()

# %%
from sklearn.model_selection import ParameterGrid

# Danh sách các tham số để thử nghiệm
param_grid = {
    "num_units": [32, 64],  # Số nơ-ron trong LSTM
    "batch_size": [32,64],  # Kích thước batch
    "learning_rate": [0.01,0.001],  # Learning rate
    "dropout_rate": [0.2, 0.5],
    'epochs': [2, 4],
}

# Lưu kết quả của từng bộ tham số
results = []

# Grid Search
for params in ParameterGrid(param_grid):
    print(f"Đang huấn luyện với tham số: {params}")

    # Xây dựng mô hình

    args=config_param(params["num_units"],params["batch_size"],params["learning_rate"],params["dropout_rate"],params["epochs"])

    # Cấu hình optimizer
    mae, rmse, r2=trainning(args)
    # Lưu kết quả
    results.append((params, rmse,r2))

# Tìm bộ tham số tốt nhất
best_params = sorted(results, key=lambda x: x[1])[0]
print("Best Parameters:", best_params)

# Tìm bộ tham số tốt nhất
best_params = sorted(results, key=lambda x: x[2])[0]
print("Best Parameters:", best_params)
# Out:
# Đang huấn luyện với tham số: {'batch_size': 32, 'dropout_rate': 0.2, 'epochs': 2, 'learning_rate': 0.01, 'num_units': 32}
# Args in experiment:
# {'target': 'q64', 'des': 'Exp', 'dropout': 0.2, 'num_workers': 10, 'gpu': 0, 'lradj': 'type1', 'devices': '0', 'use_gpu': True, 'use_multi_gpu': False, 'freq': 'h', 'checkpoints': './checkpoints/', 'bucket_size': 4, 'n_hashes': 4, 'seq_len': 180, 'label_len': 180, 'pred_len': 24, 'e_layers': 2, 'd_layers': 1, 'n_heads': 8, 'factor': 1, 'd_model': 32, 'itr': 1, 'd_ff': 2048, 'moving_avg': 25, 'distil': True, 'output_attention': False, 'patience': 3, 'learning_rate': 0.01, 'batch_size': 32, 'embed': 'timeF', 'activation': 'gelu', 'use_amp': False, 'loss': 'mse', 'train_epochs': 2, 'is_training': True, 'enc_in': 1, 'dec_in': 1, 'c_out': 1, 'root_path': '', 'data_path': '/mnt/48AC6E9BAC6E82F4/Dev/gpu-test/data/mucnuoc_gio_preprocess.csv', 'model_id': 'q64', 'model': 'Autoformer', 'data': 'custom', 'features': 'S'}
# Use GPU: cuda:0
# >>>>>>>start training : q64_Autoformer_custom_ftS_sl180_ll180_pl24_dm32_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 33049
# val 4728
# test 9477
# 	iters: 100, epoch: 1 | loss: 0.0162284
# 	speed: 0.0227s/iter; left time: 44.6896s
# 	iters: 200, epoch: 1 | loss: 0.0162278
# 	speed: 0.0149s/iter; left time: 27.7181s
# 	iters: 300, epoch: 1 | loss: 0.0143919
# 	speed: 0.0144s/iter; left time: 25.4081s
# 	iters: 400, epoch: 1 | loss: 0.0143379
# 	speed: 0.0144s/iter; left time: 24.0538s
# 	iters: 500, epoch: 1 | loss: 0.0119390
# 	speed: 0.0144s/iter; left time: 22.5607s
# 	iters: 600, epoch: 1 | loss: 0.0259288
# 	speed: 0.0145s/iter; left time: 21.2836s
# 	iters: 700, epoch: 1 | loss: 0.0152405
# 	speed: 0.0145s/iter; left time: 19.7561s
# 	iters: 800, epoch: 1 | loss: 0.0203619
# 	speed: 0.0145s/iter; left time: 18.3167s
# 	iters: 900, epoch: 1 | loss: 0.0122871
# 	speed: 0.0140s/iter; left time: 16.3170s
# 	iters: 1000, epoch: 1 | loss: 0.0098253
# 	speed: 0.0151s/iter; left time: 16.0795s
# Epoch: 1 cost time: 15.92993974685669
# Epoch: 1, Steps: 1032 | Train Loss: 0.0180019 Vali Loss: 0.0427644 Test Loss: 0.0389920
# Validation loss decreased (inf --> 0.042764).  Saving model ...
# Updating learning rate to 0.01
# 	iters: 100, epoch: 2 | loss: 0.0079450
# 	speed: 0.0890s/iter; left time: 82.9985s
# 	iters: 200, epoch: 2 | loss: 0.0065775
# 	speed: 0.0139s/iter; left time: 11.5896s
# 	iters: 300, epoch: 2 | loss: 0.0073498
# 	speed: 0.0142s/iter; left time: 10.4230s
# 	iters: 400, epoch: 2 | loss: 0.0080116
# 	speed: 0.0140s/iter; left time: 8.8934s
# 	iters: 500, epoch: 2 | loss: 0.0102680
# 	speed: 0.0144s/iter; left time: 7.6797s
# 	iters: 600, epoch: 2 | loss: 0.0025530
# 	speed: 0.0141s/iter; left time: 6.1046s
# 	iters: 500, epoch: 1 | loss: 0.0102657
# 	speed: 0.0292s/iter; left time: 45.6995s
# Epoch: 1 cost time: 15.378025770187378
# Epoch: 1, Steps: 516 | Train Loss: 0.0189641 Vali Loss: 0.0339692 Test Loss: 0.0284057
# Validation loss decreased (inf --> 0.033969).  Saving model ...
# Updating learning rate to 0.001
# 	iters: 100, epoch: 2 | loss: 0.0136550
# 	speed: 0.0919s/iter; left time: 133.2095s
# 	iters: 200, epoch: 2 | loss: 0.0124344
# 	speed: 0.0271s/iter; left time: 36.5132s
# 	iters: 300, epoch: 2 | loss: 0.0146795
# 	speed: 0.0271s/iter; left time: 33.8891s
# 	iters: 400, epoch: 2 | loss: 0.0066741
# 	speed: 0.0277s/iter; left time: 31.7813s
# 	iters: 500, epoch: 2 | loss: 0.0057225
# 	speed: 0.0291s/iter; left time: 30.5428s
# Epoch: 2 cost time: 15.318799018859863
# Epoch: 2, Steps: 516 | Train Loss: 0.0103759 Vali Loss: 0.0205728 Test Loss: 0.0208363
# Validation loss decreased (0.033969 --> 0.020573).  Saving model ...
# Updating learning rate to 0.0005
# 	iters: 100, epoch: 3 | loss: 0.0081451
# 	speed: 0.0948s/iter; left time: 88.4691s
# 	iters: 200, epoch: 3 | loss: 0.0059470
# 	speed: 0.0282s/iter; left time: 23.4528s
# 	iters: 300, epoch: 3 | loss: 0.0065234
# 	speed: 0.0275s/iter; left time: 20.1237s
# 	iters: 400, epoch: 3 | loss: 0.0085784
# 	speed: 0.0297s/iter; left time: 18.7708s
# 	iters: 500, epoch: 3 | loss: 0.0061652
# 	speed: 0.0267s/iter; left time: 14.2280s
# Epoch: 3 cost time: 15.429224491119385
# Epoch: 3, Steps: 516 | Train Loss: 0.0074925 Vali Loss: 0.0197755 Test Loss: 0.0196470
# Validation loss decreased (0.020573 --> 0.019776).  Saving model ...
# Updating learning rate to 0.00025
# 	iters: 100, epoch: 4 | loss: 0.0046504
# 	speed: 0.0951s/iter; left time: 39.6455s
# 	iters: 200, epoch: 4 | loss: 0.0063236
# 	speed: 0.0298s/iter; left time: 9.4492s
# 	iters: 300, epoch: 4 | loss: 0.0045618
# 	speed: 0.0302s/iter; left time: 6.5541s
# 	iters: 400, epoch: 4 | loss: 0.0048238
# 	speed: 0.0271s/iter; left time: 3.1752s
# 	iters: 500, epoch: 4 | loss: 0.0061459
# 	speed: 0.0279s/iter; left time: 0.4740s
# Epoch: 4 cost time: 15.89783000946045
# Epoch: 4, Steps: 516 | Train Loss: 0.0064139 Vali Loss: 0.0198258 Test Loss: 0.0197058
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 0.000125
# >>>>>>>testing : q64_Autoformer_custom_ftS_sl180_ll180_pl24_dm64_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 9477
# test shape: (9477, 24, 1) (9477, 24, 1)
# test shape: (9477, 24, 1) (9477, 24, 1)
# rmse:0.14057153463363647, mae:0.1062578484416008, r2:0.973706066608429
# Best Parameters: ({'batch_size': 64, 'dropout_rate': 0.2, 'epochs': 2, 'learning_rate': 0.001, 'num_units': 64}, np.float32(0.12320031), np.float32(0.9798031))
# Best Parameters: ({'batch_size': 64, 'dropout_rate': 0.5, 'epochs': 2, 'learning_rate': 0.01, 'num_units': 64}, np.float32(0.20019047), np.float32(0.9466729))

# %%
os.chdir("tatrach-autoformer-main")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2153837708.py in <cell line: 0>()
# ----> 1 os.chdir("tatrach-autoformer-main")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tatrach-autoformer-main'

# %%
import os

# In ra thư mục hiện tại
print("Current working directory:", os.getcwd())

# Liệt kê toàn bộ file/thư mục trong thư mục hiện tại
print("Files here:", os.listdir("."))
# Out:
# Current working directory: /content/tatrach-autoformer-main
# Files here: ['exp', 'run.py', 'utils', 'layers', 'predict.ipynb', 'pic', 'environment.yml', 'dataset', '.gitignore', 'tatrach.rar', 'Dockerfile', 'README.md', 'tatrach.ipynb', 'models', 'LICENSE', 'Makefile', 'data_provider', 'requirements.txt', 'scripts']

# %%
with open('exp/exp_main.py', 'r') as f:
    print(f.read())
# Out:
# import logging
# logging.basicConfig(format='%(asctime)s,%(msecs)03d %(levelname)-8s [%(filename)s:%(lineno)d] %(message)s',
#     datefmt='%Y-%m-%d:%H:%M:%S',
#     level=logging.INFO)
#
# from data_provider.data_factory import data_provider
# from exp.exp_basic import Exp_Basic
# from models import Informer, Autoformer, Transformer, Reformer
# from utils.tools import EarlyStopping, adjust_learning_rate, visual
# from utils.metrics import metric
#
# import numpy as np
# import torch
# import torch.nn as nn
# from torch import optim
#
# import os
# import time
#
# import warnings
# import matplotlib.pyplot as plt
# import numpy as np
#
# warnings.filterwarnings('ignore')
#
#
# class Exp_Main(Exp_Basic):
#     def __init__(self, args):
#         super(Exp_Main, self).__init__(args)
#
#     def _build_model(self):
#         model_dict = {
#             'Autoformer': Autoformer,
#             'Transformer': Transformer,
#             'Informer': Informer,
#             'Reformer': Reformer,
#         }
#         model = model_dict[self.args.model].Model(self.args).float()
#
#         if self.args.use_multi_gpu and self.args.use_gpu:
#             model = nn.DataParallel(model, device_ids=self.args.device_ids)
#         return model
#
#     def _get_data(self, flag):
#         data_set, data_loader = data_provider(self.args, flag)
#         return data_set, data_loader
#
#     def _select_optimizer(self):
#         model_optim = optim.Adam(self.model.parameters(), lr=self.args.learning_rate)
#         return model_optim
#
#     def _select_criterion(self):
#         criterion = nn.MSELoss()
#         return criterion
#
#     def _predict(self, batch_x, batch_y, batch_x_mark, batch_y_mark):
#         # decoder input
#         dec_inp = torch.zeros_like(batch_y[:, -self.args.pred_len:, :]).float()
#         dec_inp = torch.cat([batch_y[:, :self.args.label_len, :], dec_inp], dim=1).float().to(self.device)
#         # encoder - decoder
#
#         def _run_model():
#             outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
#             if self.args.output_attention:
#                 outputs = outputs[0]
#             return outputs
#
#         if self.args.use_amp:
#             with torch.cuda.amp.autocast():
#                 outputs = _run_model()
#         else:
#             outputs = _run_model()
#
#         f_dim = -1 if self.args.features == 'MS' else 0
#         outputs = outputs[:, -self.args.pred_len:, f_dim:]
#         batch_y = batch_y[:, -self.args.pred_len:, f_dim:].to(self.device)
#
#         return outputs, batch_y
#
#     def vali(self, vali_data, vali_loader, criterion):
#         total_loss = []
#         self.model.eval()
#         with torch.no_grad():
#             for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(vali_loader):
#                 batch_x = batch_x.float().to(self.device)
#                 batch_y = batch_y.float()
#
#                 batch_x_mark = batch_x_mark.float().to(self.device)
#                 batch_y_mark = batch_y_mark.float().to(self.device)
#
#                 outputs, batch_y = self._predict(batch_x, batch_y, batch_x_mark, batch_y_mark)
#
#                 pred = outputs.detach().cpu()
#                 true = batch_y.detach().cpu()
#
#                 loss = criterion(pred, true)
#
#                 total_loss.append(loss)
#         total_loss = np.average(total_loss)
#         self.model.train()
#         return total_loss
#
#     def train(self, setting):
#         train_data, train_loader = self._get_data(flag='train')
#         vali_data, vali_loader = self._get_data(flag='val')
#         test_data, test_loader = self._get_data(flag='test')
#
#         path = os.path.join(self.args.checkpoints, setting)
#         if not os.path.exists(path):
#             os.makedirs(path)
#
#         time_now = time.time()
#
#         train_steps = len(train_loader)
#         early_stopping = EarlyStopping(patience=self.args.patience, verbose=True)
#
#         model_optim = self._select_optimizer()
#         criterion = self._select_criterion()
#
#         if self.args.use_amp:
#             scaler = torch.cuda.amp.GradScaler()
#
#         for epoch in range(self.args.train_epochs):
#             iter_count = 0
#             train_loss = []
#
#             self.model.train()
#             epoch_time = time.time()
#             for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(train_loader):
#                 iter_count += 1
#                 model_optim.zero_grad()
#                 batch_x = batch_x.float().to(self.device)
#
#                 batch_y = batch_y.float().to(self.device)
#                 batch_x_mark = batch_x_mark.float().to(self.device)
#                 batch_y_mark = batch_y_mark.float().to(self.device)
#
#                 outputs, batch_y = self._predict(batch_x, batch_y, batch_x_mark, batch_y_mark)
#
#                 loss = criterion(outputs, batch_y)
#                 train_loss.append(loss.item())
#
#                 if (i + 1) % 100 == 0:
#                     print("\titers: {0}, epoch: {1} | loss: {2:.7f}".format(i + 1, epoch + 1, loss.item()))
#                     speed = (time.time() - time_now) / iter_count
#                     left_time = speed * ((self.args.train_epochs - epoch) * train_steps - i)
#                     print('\tspeed: {:.4f}s/iter; left time: {:.4f}s'.format(speed, left_time))
#                     iter_count = 0
#                     time_now = time.time()
#
#                 if self.args.use_amp:
#                     scaler.scale(loss).backward()
#                     scaler.step(model_optim)
#                     scaler.update()
#                 else:
#                     loss.backward()
#                     model_optim.step()
#
#             print("Epoch: {} cost time: {}".format(epoch + 1, time.time() - epoch_time))
#             train_loss = np.average(train_loss)
#             vali_loss = self.vali(vali_data, vali_loader, criterion)
#             test_loss = self.vali(test_data, test_loader, criterion)
#
#             print("Epoch: {0}, Steps: {1} | Train Loss: {2:.7f} Vali Loss: {3:.7f} Test Loss: {4:.7f}".format(
#                 epoch + 1, train_steps, train_loss, vali_loss, test_loss))
#             early_stopping(vali_loss, self.model, path)
#             if early_stopping.early_stop:
#                 print("Early stopping")
#                 break
#
#             adjust_learning_rate(model_optim, epoch + 1, self.args)
#
#         best_model_path = path + '/' + 'checkpoint.pth'
#         self.model.load_state_dict(torch.load(best_model_path))
#
#         return
#
#     def test(self, setting, test=0):
#         test_data, test_loader = self._get_data(flag='test')
#         if test:
#             print('loading model')
#             self.model.load_state_dict(torch.load(os.path.join('./checkpoints/' + setting, 'checkpoint.pth')))
#
#         preds = []
#         trues = []
#         folder_path = './test_results/' + setting + '/'
#         if not os.path.exists(folder_path):
#             os.makedirs(folder_path)
#
#         self.model.eval()
#         with torch.no_grad():
#             for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(test_loader):
#                 batch_x = batch_x.float().to(self.device)
#                 batch_y = batch_y.float().to(self.device)
#
#                 batch_x_mark = batch_x_mark.float().to(self.device)
#                 batch_y_mark = batch_y_mark.float().to(self.device)
#
#                 outputs, batch_y = self._predict(batch_x, batch_y, batch_x_mark, batch_y_mark)
#
#                 outputs = outputs.detach().cpu().numpy()
#                 batch_y = batch_y.detach().cpu().numpy()
#
#                 pred = outputs  # outputs.detach().cpu().numpy()  # .squeeze()
#                 true = batch_y  # batch_y.detach().cpu().numpy()  # .squeeze()
#
#                 preds.append(pred)
#                 trues.append(true)
#                 if i % 20 == 0:
#                     input = batch_x.detach().cpu().numpy()
#                     gt = np.concatenate((input[0, :, -1], true[0, :, -1]), axis=0)
#                     pd = np.concatenate((input[0, :, -1], pred[0, :, -1]), axis=0)
#                     visual(gt, pd, os.path.join(folder_path, str(i) + '.pdf'))
#
#         preds = np.concatenate(preds, axis=0)
#         trues = np.concatenate(trues, axis=0)
#         print('test shape:', preds.shape, trues.shape)
#         preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])
#         trues = trues.reshape(-1, trues.shape[-2], trues.shape[-1])
#         print('test shape:', preds.shape, trues.shape)
#
#         # result save
#         folder_path = './results/' + setting + '/'
#         if not os.path.exists(folder_path):
#             os.makedirs(folder_path)
#
#         mae, mse, rmse, mape, mspe, r2 = metric(preds, trues)
#         print("aaaaaaaaaaaaaa", r2)
#         print('mse:{}, mae:{}, r2:{}'.format(mse, mae, r2))
#         f = open("result.txt", 'a')
#         f.write(setting + "  \n")
#         f.write('mse:{}, mae:{}, r2:{}'.format(mse, mae, r2))
#         f.write('\n')
#         f.write('\n')
#         f.close()
#
#         np.save(folder_path + 'metrics.npy', np.array([mae, mse, rmse, mape, mspe, r2]))
#         np.save(folder_path + 'pred.npy', preds)
#         np.save(folder_path + 'true.npy', trues)
#
#
#         return mae, rmse, r2
#
#     def predict(self, setting, load=False):
#         pred_data, pred_loader = self._get_data(flag='pred')
#
#         if load:
#             path = os.path.join(self.args.checkpoints, setting)
#             best_model_path = path + '/' + 'checkpoint.pth'
#             logging.info(best_model_path)
#             self.model.load_state_dict(torch.load(best_model_path))
#
#         preds = []
#
#         self.model.eval()
#         with torch.no_grad():
#             for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(pred_loader):
#                 batch_x = batch_x.float().to(self.device)
#                 batch_y = batch_y.float()
#                 batch_x_mark = batch_x_mark.float().to(self.device)
#                 batch_y_mark = batch_y_mark.float().to(self.device)
#
#                 outputs, batch_y = self._predict(batch_x, batch_y, batch_x_mark, batch_y_mark)
#
#                 pred = outputs.detach().cpu().numpy()  # .squeeze()
#                 preds.append(pred)
#
#         preds = np.array(preds)
#         preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])
#
#         # result save
#         folder_path = './results/' + setting + '/'
#         if not os.path.exists(folder_path):
#             os.makedirs(folder_path)
#
#         np.save(folder_path + 'real_prediction.npy', preds)
#
#         return
